# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Datasets/BigmacPrice.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv('Datasets/BigMacPrice.csv')
#       2 df
#
# NameError: name 'pd' is not defined

# %%
pd.crosstab(df.dollar_price, df.name)
# Out:
# name          Argentina  Australia  Austria  Azerbaijan  Bahrain  Belgium  \
# dollar_price
# 0.00                  0          0        0           0        0        0
# 0.67                  0          0        0           0        0        0
# 0.80                  0          0        0           0        0        0
# 0.83                  1          0        0           0        0        0
# 0.97                  0          0        0           0        0        0
# ...                 ...        ...      ...         ...      ...      ...
# 9.00                  0          0        0           0        0        0
# 9.50                  0          0        0           0        0        0
# 9.75                  0          0        0           0        0        0
# 10.25                 0          0        0           0        0        0
# 11.25                 0          0        0           0        0        0
#
# ...
